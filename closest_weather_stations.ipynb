# %%
import sys

import numpy as np
import pandas as pd

# %%
def distance(entity, stations):
    """
    Given a entity with 'latitude'/'longitude' (degrees)
    calculate its distance from each station 'lat'/'lon' (radians)
    """
    def hav(theta):
        """
        Haversine function on an angle (in radians)
        """
        return 0.5 * (1 - np.cos(theta))

    entity_lat = np.radians(entity['Latitude'])
    entity_lon = np.radians(entity['Longitude'])

    r = 6371  # in km
    h1 = hav(stations['Latitude_rad'] - entity_lat)
    h2 = np.cos(entity_lat)*np.cos(stations['Latitude_rad'])*hav(stations['Longitude_rad']-entity_lon)

    return 2 * r * np.arcsin(np.sqrt(h1 + h2))


def closest_station(entity, stations):
    """
        Returns the tmax of the station closest to the entity
    """
    return stations.iloc[distance(entity, stations).idxmin()]

# %%
lakes = pd.read_csv('reservoir_list.csv')
lakes.dropna(inplace=True)

# %%
stations = pd.read_csv('weather_station_inventory_bc.csv')
stations['Latitude_rad'] = np.radians(stations['Latitude (Decimal Degrees)'])
stations['Longitude_rad'] = np.radians(stations['Longitude (Decimal Degrees)'])

# %%
lakes.apply(closest_station, axis=1, stations=stations[stations['Climate ID'] != '1100360'])
# Out:
#                             Name          Province Climate ID  Station ID  \
# 0             HANEY UBC RF ADMIN  BRITISH COLUMBIA    1103332         776
# 2                  CLOWHOM FALLS  BRITISH COLUMBIA    1041710         303
# 4                     LAJOIE DAM  BRITISH COLUMBIA    1084490         522
# 5            PORT MOODY GLENAYRE  BRITISH COLUMBIA    1106CL2         834
# 6                   BUNTZEN LAKE  BRITISH COLUMBIA    1101140         721
# 7                   SKAGIT RIVER  BRITISH COLUMBIA    1117410         974
# 8   STAVE LAKE SEVENTYNINE CREEK  BRITISH COLUMBIA    1107689         868
# 9                         TAPPEN  BRITISH COLUMBIA    1167980        1333
# 10          COQUITLAM MUNDY PARK  BRITISH COLUMBIA    1101891         752
#
#     WMO ID  TC ID  Latitude (Decimal Degrees)  Longitude (Decimal Degrees)  \
# 0      NaN    NaN                       49.26                      -122.57
# 2      NaN    NaN                       49.72                      -123.53
# ...

# %%
distance(lakes.iloc[1], stations).idxmin()
# Out:
# 349

# %%
stations.iloc[795]
# Out:
# Name                                AGASSIZ RCS
# Province                       BRITISH COLUMBIA
# Climate ID                              1100119
# Station ID                                  706
# WMO ID                                    71113
# TC ID                                       WZA
# Latitude (Decimal Degrees)                49.24
# Longitude (Decimal Degrees)             -121.76
# Latitude                              491435000
# Longitude                           -1214537000
# Elevation (m)                              19.3
# First Year                                 1988
# Last Year                                  2019
# HLY First Year                             1994
# HLY Last Year                              2019
# DLY First Year                             1988
# DLY Last Year                              2019
# MLY First Year                             1988
# MLY Last Year                              2006
# Latitude_rad                             0.8594
# ...

# %%
lakes.iloc[0]
# Out:
# Name                                                  ALOUETTE LAKE
# ClosestStation                                              08MH148
# Longitude                                                  -122.484
# Latitude                                                    49.2872
# Link              https://www.bchydro.com/energy-in-bc/operation...
# Name: 0, dtype: object

# %%
stations[stations['Climate ID'] == '1100360']
# Out:
#               Name          Province Climate ID  Station ID  WMO ID TC ID  \
# 801  ALOUETTE LAKE  BRITISH COLUMBIA    1100360         712     NaN   NaN
#
#      Latitude (Decimal Degrees)  Longitude (Decimal Degrees)   Latitude  \
# 801                       49.28                      -122.48  491700000
#
#       Longitude  ...  First Year  Last Year  HLY First Year  HLY Last Year  \
# 801 -1222900000  ...        1924       1982             NaN            NaN
#
#      DLY First Year  DLY Last Year  MLY First Year  MLY Last Year  \
# 801          1924.0         1982.0          1924.0         1982.0
#
#      Latitude_rad  Longitude_rad
# 801      0.860098      -2.137679
#
# [1 rows x 21 columns]

# %%
First Year Last Year
# Out:
#   File "<ipython-input-10-285c983898be>", line 1
#     First Year Last Year
#              ^
# SyntaxError: invalid syntax
